# %% [markdown]
# Based on the following links to create this notebook:
#
# https://colab.research.google.com/drive/18LdlDDT87eb8cCTHZsXyS9ksQPzL3i6H
#
# https://colab.research.google.com/drive/1tug_bpg8RwrFOI8C6Ed-zo0OgD3yfnWy#scrollTo=bhsj7BTPHepg
#
# https://colab.research.google.com/drive/1tug_bpg8RwrFOI8C6Ed-zo0OgD3yfnWy
#
#
# To run Gym, you have to install prerequisites like xvbf,opengl & other python-dev packages using the following codes.

# %%
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.8).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (2.1)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay) (0.3)
# Requirement already satisfied: piglet in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: piglet-templates in /usr/local/lib/python3.7/dist-packages (from piglet) (1.1.0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (20.3.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.1.1)
# Requirement already satisfied: Parsley in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (0.36.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (1.15.0)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# This code creates a virtual display to draw game images on.
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    # %env DISPLAY = : 1

# %%
import json
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) # error only
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
import copy
from collections import deque

from IPython import display as ipythondisplay
import torch
import torchvision
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""
def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")


def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %%
# !pip install gym[box2d]
# Out:
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.19.5)
# Requirement already satisfied: box2d-py~=2.3.5; extra == "box2d" in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (2.3.8)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[box2d]) (0.16.0)

# %%
env = gym.make('LunarLanderContinuous-v2')
env.reset()
plt.imshow(env.render('rgb_array'))

# %%
state_size = env.observation_space
print("state size is:", state_size)
a = env.action_space
print("action size=", a)
state = env.reset()
print(state)
# Out:
# state size is: Box(-inf, inf, (8,), float32)
# action size= Box(-1.0, 1.0, (2,), float32)
# [ 0.00727329  1.4221375   0.7367081   0.4985361  -0.00842132 -0.16687548
#   0.          0.        ]

# %% [markdown]
# # Action Space
#             #is two floats [main engine, left-right engines].
#             # Main engine: -1..0 off, 0..+1 throttle from 50% to 100% power. Engine can't work with less than 50% power.
#             # Left-right:  -1.0..-0.5 fire left engine, +0.5..+1.0 fire right engine, -0.5..0.5 off
#             self.action_space = spaces.Box(-1, +1, (2,), dtype=np.float32)

# %% [markdown]
# # Action Space (continuous to discrete values)

# %%
class ActionSpace(object):
    def __init__(self, x_size, y_size):
        self.x_size = x_size
        self.y_size = y_size
        self.cache = {}
        self.build_actions_cache()

    def build_actions_cache(self):
        for i in range(self.x_size * self.y_size):
            self.cache[i] = self.get_value_by_key(i)

    def get_value_by_key(self, key):
        ind1 = int(key / self.y_size)
        ind2 = key % self.y_size
        value1 = 0 + ind1 * (1 / (self.x_size - 1))

        if ind1 == 0:
            value1 = -1
        if ind2 == 0:
            value2 = 0
        else:
            half = (self.y_size - 1) / 2
            if ind2 <= self.y_size/2:
                value2 = -0.5+- ind2 * (0.5 / (half))
            else:
                ind2 = ind2 - half
                value2 = 0.5 + ind2 * (0.5 / (half))

        return [value1, value2]

    def choose(self, key):
        return self.cache[key]


x_actions = 2
y_actions = 15  # y_actions must be an odd number.
all_actions = x_actions * y_actions
action_space = ActionSpace(x_actions, y_actions)

# %% [markdown]
# # DQN Model.

# %%
class DoubleDQN(nn.Module):
    def __init__(self, all_actions):
        super(DoubleDQN, self).__init__()

        self.fc1 = nn.Linear(8, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, all_actions)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return self.fc4(x)

# %% [markdown]
# # GPU/CPU

# %%
device = None
if torch.cuda.is_available():
    print("Using GPU.")
    device = torch.device('cuda:0')
else:
    print("Using CPU.")
    device = torch.device("cpu")
# Out:
# Using GPU.

# %% [markdown]
# # Replay Memory

# %%
class ReplayMemory(object):
    def __init__(self, replay_memory_size):
        self.memory = deque(maxlen=replay_memory_size)

    def size(self):
        return len(self.memory)

    def push(self, state, action, reward, observation, done):
        self.memory.append((state, action, reward, observation, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

# %% [markdown]
# # Methods

# %%
def choose_action(state, epsilon, model):
    model.eval()
    if np.random.rand() <= epsilon:
        return np.random.choice(all_actions)
    else:
        unsqueeze = state.unsqueeze(0)
        preds = model(unsqueeze)
        value, indice = torch.max(preds, 1)
        return indice[0].item()


def run_replay_experiments(model, target_model, replay_memory, optimizer, batch_size):
    optimizer.zero_grad()
    model.eval()
    target_model.eval()

    x_batch = []
    x_target = []
    samples_batch = replay_memory.sample(batch_size)

    for state, action, reward, observation, done in samples_batch:
        x_batch.append(state)
        x_target.append(observation)

    x_batch = torch.stack(x_batch).to(device)
    x_target = torch.stack(x_target).to(device)

    model_target_preds = model(x_target)
    target_preds = target_model(x_target)
    _, indices = torch.max(model_target_preds, 1)

    max_values = []
    for i in range(len(indices)):
        max_values.append(target_preds[i][indices[i]])
    model.train()

    model_preds = model(x_batch)
    model_preds_clone = model_preds.clone()

    for index, (state, action, reward, observation, done) in enumerate(samples_batch):
        if done:
            model_preds_clone[index][action] = reward
        else:
            model_preds_clone[index][action] = reward + gama * max_values[index]

    loss = F.smooth_l1_loss(model_preds, model_preds_clone)
    loss.backward()
    optimizer.step()

# %% [markdown]
# # Parameters.

# %%
epsilon = 1
epsilon_decay = 0.975

batch_size = 256
max_iterations = 50000

reset_target = 200
steps_per_action = 1
replay_memory_size = 20000

gama = 0.99
lr = 0.00005

# %% [markdown]
# # Training the model.

# %%
env = wrap_env(env)


model = DoubleDQN(all_actions)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

if not next(model.parameters()).is_cuda:
    print('The neural network model is not working on GPU!')

average100 = deque(maxlen=100)
replay_memory = ReplayMemory(replay_memory_size)

results_memory = []
steps=0
for iteration in range(max_iterations):
    state = env.reset()
    total_reward = 0
    done = False
    state = torch.from_numpy(state).to(device)

    while not done:
        action = choose_action(state, epsilon, model)
        converted_action = action_space.choose(action)

        observation, reward, done, _ = env.step(converted_action)
        observation = torch.from_numpy(observation).to(device)
        total_reward += reward

        replay_memory.push(state, action, reward, observation, done)
        state = observation


        for i in range(steps_per_action):
            if steps % reset_target == 0:
                target_model = copy.deepcopy(model)
                target_model.to(device)  
            steps=steps+1        
            if replay_memory.size() >= batch_size:
                run_replay_experiments(model, target_model, replay_memory, optimizer, batch_size)


    average100.append(total_reward)
    epsilon *= epsilon_decay
    print(f'Iteration: {iteration} | Epsilon: {round(epsilon, 2)} | Last Reward: {round(reward, 2)} | Average100: {round(np.average(average100))} | Total Reward: {total_reward}')
    results_memory.append((iteration, round(np.average(average100))))

    if len(average100) >= 100 and np.average(average100) >= 200:
        print(f'Finished after {iteration-100} iterations.')
        break
# Out:
# Iteration: 0 | Epsilon: 0.97 | Last Reward: -100 | Average100: -374 | Total Reward: -374.02281568070106
# Iteration: 1 | Epsilon: 0.95 | Last Reward: -100 | Average100: -311 | Total Reward: -247.26800826790983
# Iteration: 2 | Epsilon: 0.93 | Last Reward: -100 | Average100: -321 | Total Reward: -342.3024826035188
# Iteration: 3 | Epsilon: 0.9 | Last Reward: -100 | Average100: -405 | Total Reward: -658.3988486649622
# Iteration: 4 | Epsilon: 0.88 | Last Reward: -100 | Average100: -372 | Total Reward: -237.56775873937707
# Iteration: 5 | Epsilon: 0.86 | Last Reward: -100 | Average100: -402 | Total Reward: -549.5507485445402
# Iteration: 6 | Epsilon: 0.84 | Last Reward: -100 | Average100: -387 | Total Reward: -298.58092294882044
# Iteration: 7 | Epsilon: 0.82 | Last Reward: -100 | Average100: -347 | Total Reward: -67.4595637965728
# Iteration: 8 | Epsilon: 0.8 | Last Reward: -100 | Average100: -356 | Total Reward: -428.24544904347164
# Iteration: 9 | Epsilon: 0.78 | Last Reward: -100 | Average100: -349 | Total Reward: -282.6055123181677
# Iteration: 10 | Epsilon: 0.76 | Last Reward: -100 | Average100: -318 | Total Reward: -8.482312803090295
# Iteration: 11 | Epsilon: 0.74 | Last Reward: -100 | Average100: -298 | Total Reward: -78.4001555449625
# Iteration: 12 | Epsilon: 0.72 | Last Reward: -100 | Average100: -313 | Total Reward: -496.2903491829535
# Iteration: 13 | Epsilon: 0.7 | Last Reward: -100 | Average100: -302 | Total Reward: -165.23655990654242
# Iteration: 14 | Epsilon: 0.68 | Last Reward: -100 | Average100: -297 | Total Reward: -222.7198094312544
# Iteration: 15 | Epsilon: 0.67 | Last Reward: -100 | Average100: -291 | Total Reward: -198.15588176187828
# Iteration: 16 | Epsilon: 0.65 | Last Reward: 1.88 | Average100: -279 | Total Reward: -81.31975576932312
# Iteration: 17 | Epsilon: 0.63 | Last Reward: -7.58 | Average100: -265 | Total Reward: -29.75464813493735
# Iteration: 18 | Epsilon: 0.62 | Last Reward: 0.36 | Average100: -251 | Total Reward: -8.480225286109258
# Iteration: 19 | Epsilon: 0.6 | Last Reward: -0.39 | Average100: -238 | Total Reward: 6.023543751571116
# Iteration: 20 | Epsilon: 0.59 | Last Reward: -4.4 | Average100: -226 | Total Reward: 21.97307624586116
# Iteration: 21 | Epsilon: 0.57 | Last Reward: -100 | Average100: -214 | Total Reward: 45.94854995953335
# Iteration: 22 | Epsilon: 0.56 | Last Reward: -0.18 | Average100: -204 | Total Reward: 17.32911425036171
# Iteration: 23 | Epsilon: 0.54 | Last Reward: 0.74 | Average100: -198 | Total Reward: -74.07255024469409
# Iteration: 24 | Epsilon: 0.53 | Last Reward: -0.09 | Average100: -189 | Total Reward: 34.694857816786204
# Iteration: 25 | Epsilon: 0.52 | Last Reward: -8.0 | Average100: -182 | Total Reward: -19.883572762938392
# Iteration: 26 | Epsilon: 0.5 | Last Reward: -1.71 | Average100: -179 | Total Reward: -88.95540214200736
# Iteration: 27 | Epsilon: 0.49 | Last Reward: -0.19 | Average100: -177 | Total Reward: -131.59725436901775
# Iteration: 28 | Epsilon: 0.48 | Last Reward: 3.18 | Average100: -173 | Total Reward: -58.26244561712992
# Iteration: 29 | Epsilon: 0.47 | Last Reward: 2.81 | Average100: -169 | Total Reward: -42.400812456171366
# Iteration: 30 | Epsilon: 0.46 | Last Reward: -0.13 | Average100: -163 | Total Reward: 1.612806462427906
# Iteration: 31 | Epsilon: 0.44 | Last Reward: -1.22 | Average100: -157 | Total Reward: 24.814769960304883
# Iteration: 32 | Epsilon: 0.43 | Last Reward: -0.02 | Average100: -152 | Total Reward: 7.9355254932106645
# Iteration: 33 | Epsilon: 0.42 | Last Reward: -100 | Average100: -152 | Total Reward: -128.82031888467597
# Iteration: 34 | Epsilon: 0.41 | Last Reward: -1.09 | Average100: -149 | Total Reward: -67.86286528920286
# Iteration: 35 | Epsilon: 0.4 | Last Reward: -2.15 | Average100: -147 | Total Reward: -58.30986531543938
# Iteration: 36 | Epsilon: 0.39 | Last Reward: 0.84 | Average100: -143 | Total Reward: -24.31600624396166
# Iteration: 37 | Epsilon: 0.38 | Last Reward: 1.27 | Average100: -140 | Total Reward: -24.46363272604117
# Iteration: 38 | Epsilon: 0.37 | Last Reward: -100 | Average100: -136 | Total Reward: 28.25099120019371
# Iteration: 39 | Epsilon: 0.36 | Last Reward: -0.27 | Average100: -134 | Total Reward: -50.78604954926604
# Iteration: 40 | Epsilon: 0.35 | Last Reward: -0.05 | Average100: -130 | Total Reward: 36.38144302851041
# Iteration: 41 | Epsilon: 0.35 | Last Reward: -0.84 | Average100: -128 | Total Reward: -50.2399015997048
# Iteration: 42 | Epsilon: 0.34 | Last Reward: 0.06 | Average100: -124 | Total Reward: 38.45851431271999
# Iteration: 43 | Epsilon: 0.33 | Last Reward: 1.7 | Average100: -120 | Total Reward: 39.61590305150158
# Iteration: 44 | Epsilon: 0.32 | Last Reward: 2.55 | Average100: -116 | Total Reward: 70.96102370715074
# Iteration: 45 | Epsilon: 0.31 | Last Reward: -4.78 | Average100: -113 | Total Reward: 26.724472264804042
# Iteration: 46 | Epsilon: 0.3 | Last Reward: 0.09 | Average100: -109 | Total Reward: 48.66497394397901
# Iteration: 47 | Epsilon: 0.3 | Last Reward: -0.23 | Average100: -108 | Total Reward: -48.42517547205111
# Iteration: 48 | Epsilon: 0.29 | Last Reward: -100 | Average100: -108 | Total Reward: -105.82306516313692
# Iteration: 49 | Epsilon: 0.28 | Last Reward: 0.46 | Average100: -105 | Total Reward: 42.29979029816449
# Iteration: 50 | Epsilon: 0.27 | Last Reward: 9.14 | Average100: -103 | Total Reward: 4.606700984247869
# Iteration: 51 | Epsilon: 0.27 | Last Reward: 0.92 | Average100: -102 | Total Reward: -50.31269691358162
# Iteration: 52 | Epsilon: 0.26 | Last Reward: -1.14 | Average100: -100 | Total Reward: 22.336124013089215
# Iteration: 53 | Epsilon: 0.25 | Last Reward: 11.65 | Average100: -97 | Total Reward: 41.115568638715814
# Iteration: 54 | Epsilon: 0.25 | Last Reward: 2.58 | Average100: -95 | Total Reward: -8.114300448041817
# Iteration: 55 | Epsilon: 0.24 | Last Reward: 0.73 | Average100: -93 | Total Reward: 20.190668592233223
# Iteration: 56 | Epsilon: 0.24 | Last Reward: -100 | Average100: -92 | Total Reward: -28.632331440662497
# Iteration: 57 | Epsilon: 0.23 | Last Reward: 0.69 | Average100: -90 | Total Reward: 57.92887361116793
# Iteration: 58 | Epsilon: 0.22 | Last Reward: -10.54 | Average100: -87 | Total Reward: 78.87117403175492
# Iteration: 59 | Epsilon: 0.22 | Last Reward: -2.18 | Average100: -84 | Total Reward: 68.99135937915524
# Iteration: 60 | Epsilon: 0.21 | Last Reward: 0.6 | Average100: -81 | Total Reward: 88.6992461441235
# Iteration: 61 | Epsilon: 0.21 | Last Reward: 0.73 | Average100: -79 | Total Reward: 67.77277688689907
# Iteration: 62 | Epsilon: 0.2 | Last Reward: 0.12 | Average100: -76 | Total Reward: 79.46368548710214
# Iteration: 63 | Epsilon: 0.2 | Last Reward: -0.3 | Average100: -74 | Total Reward: 77.03703408280012
# Iteration: 64 | Epsilon: 0.19 | Last Reward: -0.02 | Average100: -71 | Total Reward: 92.43465274607583
# Iteration: 65 | Epsilon: 0.19 | Last Reward: 1.09 | Average100: -69 | Total Reward: 83.0948664455561
# Iteration: 66 | Epsilon: 0.18 | Last Reward: -1.28 | Average100: -67 | Total Reward: 73.13608458574205
# Iteration: 67 | Epsilon: 0.18 | Last Reward: 11.05 | Average100: -65 | Total Reward: 59.71866363168226
# Iteration: 68 | Epsilon: 0.17 | Last Reward: -0.02 | Average100: -63 | Total Reward: 68.1207424105296
# Iteration: 69 | Epsilon: 0.17 | Last Reward: -0.03 | Average100: -61 | Total Reward: 60.92808259036578
# Iteration: 70 | Epsilon: 0.17 | Last Reward: -0.01 | Average100: -60 | Total Reward: 37.856732681231065
# Iteration: 71 | Epsilon: 0.16 | Last Reward: 0.02 | Average100: -58 | Total Reward: 105.81196746728438
# Iteration: 72 | Epsilon: 0.16 | Last Reward: -1.13 | Average100: -55 | Total Reward: 141.67614510340283
# Iteration: 73 | Epsilon: 0.15 | Last Reward: 10.96 | Average100: -53 | Total Reward: 68.86961448111543
# Iteration: 74 | Epsilon: 0.15 | Last Reward: -0.33 | Average100: -52 | Total Reward: 60.86551359077124
# Iteration: 75 | Epsilon: 0.15 | Last Reward: -0.27 | Average100: -50 | Total Reward: 107.28865823105917
# Iteration: 76 | Epsilon: 0.14 | Last Reward: -0.16 | Average100: -47 | Total Reward: 121.65780210752696
# Iteration: 77 | Epsilon: 0.14 | Last Reward: 1.16 | Average100: -45 | Total Reward: 117.78477334601655
# Iteration: 78 | Epsilon: 0.14 | Last Reward: 100 | Average100: -42 | Total Reward: 220.6528014690183
# Iteration: 79 | Epsilon: 0.13 | Last Reward: 10.95 | Average100: -40 | Total Reward: 126.19531992290703
# Iteration: 80 | Epsilon: 0.13 | Last Reward: 2.33 | Average100: -40 | Total Reward: -57.30591102015596
# Iteration: 81 | Epsilon: 0.13 | Last Reward: -0.31 | Average100: -38 | Total Reward: 104.56293138410267
# Iteration: 82 | Epsilon: 0.12 | Last Reward: -0.57 | Average100: -37 | Total Reward: 101.21875795155712
# Iteration: 83 | Epsilon: 0.12 | Last Reward: 0.42 | Average100: -35 | Total Reward: 127.56336436438104
# Iteration: 84 | Epsilon: 0.12 | Last Reward: -0.12 | Average100: -33 | Total Reward: 73.62617178235912
# Iteration: 85 | Epsilon: 0.11 | Last Reward: 1.04 | Average100: -33 | Total Reward: -25.275139749726343
# Iteration: 86 | Epsilon: 0.11 | Last Reward: -100 | Average100: -35 | Total Reward: -171.18637436417353
# Iteration: 87 | Epsilon: 0.11 | Last Reward: -100 | Average100: -36 | Total Reward: -148.18487147825908
# Iteration: 88 | Epsilon: 0.11 | Last Reward: 100 | Average100: -34 | Total Reward: 137.3702547378627
# Iteration: 89 | Epsilon: 0.1 | Last Reward: -0.76 | Average100: -33 | Total Reward: 87.42469932566108
# Iteration: 90 | Epsilon: 0.1 | Last Reward: 100 | Average100: -31 | Total Reward: 179.99699822118987
# Iteration: 91 | Epsilon: 0.1 | Last Reward: -0.16 | Average100: -29 | Total Reward: 74.46283027356282
# Iteration: 92 | Epsilon: 0.09 | Last Reward: 100 | Average100: -27 | Total Reward: 208.97007921544275
# Iteration: 93 | Epsilon: 0.09 | Last Reward: 100 | Average100: -24 | Total Reward: 247.74001502660693
# Iteration: 94 | Epsilon: 0.09 | Last Reward: 100 | Average100: -21 | Total Reward: 220.41264509497861
# Iteration: 95 | Epsilon: 0.09 | Last Reward: 100 | Average100: -19 | Total Reward: 219.3434206371216
# Iteration: 96 | Epsilon: 0.09 | Last Reward: 100 | Average100: -16 | Total Reward: 264.34272881729066
# Iteration: 97 | Epsilon: 0.08 | Last Reward: -1.87 | Average100: -15 | Total Reward: 55.81035007508196
# Iteration: 98 | Epsilon: 0.08 | Last Reward: 100 | Average100: -12 | Total Reward: 255.9840054672952
# Iteration: 99 | Epsilon: 0.08 | Last Reward: 100 | Average100: -10 | Total Reward: 208.31289204091672
# Iteration: 100 | Epsilon: 0.08 | Last Reward: 100 | Average100: -4 | Total Reward: 202.7695236356039
# Iteration: 101 | Epsilon: 0.08 | Last Reward: -0.18 | Average100: -1 | Total Reward: 93.20076498159426
# Iteration: 102 | Epsilon: 0.07 | Last Reward: 0.14 | Average100: 4 | Total Reward: 137.16031688456602
# Iteration: 103 | Epsilon: 0.07 | Last Reward: 0.07 | Average100: 11 | Total Reward: 57.92675041214713
# Iteration: 104 | Epsilon: 0.07 | Last Reward: -0.26 | Average100: 14 | Total Reward: 120.24487383786898
# Iteration: 105 | Epsilon: 0.07 | Last Reward: -100 | Average100: 18 | Total Reward: -217.8620212393581
# Iteration: 106 | Epsilon: 0.07 | Last Reward: 0.01 | Average100: 22 | Total Reward: 162.6931846112657
# Iteration: 107 | Epsilon: 0.06 | Last Reward: 100 | Average100: 26 | Total Reward: 281.87249675536157
# Iteration: 108 | Epsilon: 0.06 | Last Reward: 100 | Average100: 33 | Total Reward: 285.1285087332161
# Iteration: 109 | Epsilon: 0.06 | Last Reward: 100 | Average100: 37 | Total Reward: 149.86667852141449
# Iteration: 110 | Epsilon: 0.06 | Last Reward: 0.02 | Average100: 38 | Total Reward: 55.333706334157256
# Iteration: 111 | Epsilon: 0.06 | Last Reward: -1.16 | Average100: 39 | Total Reward: 14.21901671539404
# Iteration: 112 | Epsilon: 0.06 | Last Reward: -0.19 | Average100: 44 | Total Reward: 52.88914923535718
# Iteration: 113 | Epsilon: 0.06 | Last Reward: 0.04 | Average100: 47 | Total Reward: 140.05555656912207
# Iteration: 114 | Epsilon: 0.05 | Last Reward: 0.08 | Average100: 52 | Total Reward: 190.62529900723686
# Iteration: 115 | Epsilon: 0.05 | Last Reward: 100 | Average100: 56 | Total Reward: 235.1754560050397
# Iteration: 116 | Epsilon: 0.05 | Last Reward: 0.04 | Average100: 58 | Total Reward: 148.81200477942954
# Iteration: 117 | Epsilon: 0.05 | Last Reward: 100 | Average100: 61 | Total Reward: 210.59280108521176
# Iteration: 118 | Epsilon: 0.05 | Last Reward: 100 | Average100: 63 | Total Reward: 221.7964355337492
# Iteration: 119 | Epsilon: 0.05 | Last Reward: 100 | Average100: 65 | Total Reward: 221.1047710835922
# Iteration: 120 | Epsilon: 0.05 | Last Reward: 100 | Average100: 67 | Total Reward: 250.71190504310007
# Iteration: 121 | Epsilon: 0.05 | Last Reward: 0.57 | Average100: 68 | Total Reward: 114.78486920629034
# Iteration: 122 | Epsilon: 0.04 | Last Reward: -0.12 | Average100: 69 | Total Reward: 127.83763348866324
# Iteration: 123 | Epsilon: 0.04 | Last Reward: 100 | Average100: 73 | Total Reward: 263.82378766847097
# Iteration: 124 | Epsilon: 0.04 | Last Reward: 100 | Average100: 74 | Total Reward: 218.04469835072936
# Iteration: 125 | Epsilon: 0.04 | Last Reward: -0.13 | Average100: 76 | Total Reward: 135.7463911432878
# Iteration: 126 | Epsilon: 0.04 | Last Reward: 0.07 | Average100: 78 | Total Reward: 161.25985798923418
# Iteration: 127 | Epsilon: 0.04 | Last Reward: -2.7 | Average100: 81 | Total Reward: 138.87575104876709
# Iteration: 128 | Epsilon: 0.04 | Last Reward: -100 | Average100: 82 | Total Reward: 42.11803623092109
# Iteration: 129 | Epsilon: 0.04 | Last Reward: -0.01 | Average100: 84 | Total Reward: 146.13780828833978
# Iteration: 130 | Epsilon: 0.04 | Last Reward: 0.25 | Average100: 85 | Total Reward: 138.23179719343818
# Iteration: 131 | Epsilon: 0.04 | Last Reward: 100 | Average100: 88 | Total Reward: 258.98446603201546
# Iteration: 132 | Epsilon: 0.03 | Last Reward: 100 | Average100: 90 | Total Reward: 227.04331959587472
# Iteration: 133 | Epsilon: 0.03 | Last Reward: -0.38 | Average100: 93 | Total Reward: 143.7540518485764
# Iteration: 134 | Epsilon: 0.03 | Last Reward: 0.09 | Average100: 95 | Total Reward: 154.34396961497202
# Iteration: 135 | Epsilon: 0.03 | Last Reward: 0.02 | Average100: 97 | Total Reward: 124.36872460808688
# Iteration: 136 | Epsilon: 0.03 | Last Reward: 0.08 | Average100: 98 | Total Reward: 141.5255018209387
# Iteration: 137 | Epsilon: 0.03 | Last Reward: 100 | Average100: 101 | Total Reward: 278.32823897027265
# Iteration: 138 | Epsilon: 0.03 | Last Reward: 0.0 | Average100: 103 | Total Reward: 152.27470667294887
# Iteration: 139 | Epsilon: 0.03 | Last Reward: -100 | Average100: 103 | Total Reward: 5.172605352511724
# Iteration: 140 | Epsilon: 0.03 | Last Reward: 100 | Average100: 106 | Total Reward: 277.45049379155137
# Iteration: 141 | Epsilon: 0.03 | Last Reward: 100 | Average100: 109 | Total Reward: 281.1090166943071
# Iteration: 142 | Epsilon: 0.03 | Last Reward: -100 | Average100: 109 | Total Reward: 13.04251016097318
# Iteration: 143 | Epsilon: 0.03 | Last Reward: 100 | Average100: 111 | Total Reward: 267.6467946514623
# Iteration: 144 | Epsilon: 0.03 | Last Reward: 100 | Average100: 113 | Total Reward: 259.01503979866493
# Iteration: 145 | Epsilon: 0.02 | Last Reward: 0.04 | Average100: 114 | Total Reward: 124.51075165883816
# Iteration: 146 | Epsilon: 0.02 | Last Reward: 100 | Average100: 116 | Total Reward: 254.75744542352814
# Iteration: 147 | Epsilon: 0.02 | Last Reward: 100 | Average100: 119 | Total Reward: 229.00066966159437
# Iteration: 148 | Epsilon: 0.02 | Last Reward: 100 | Average100: 122 | Total Reward: 241.9668215541815
# Iteration: 149 | Epsilon: 0.02 | Last Reward: -0.24 | Average100: 120 | Total Reward: -117.12796198663125
# Iteration: 150 | Epsilon: 0.02 | Last Reward: 100 | Average100: 123 | Total Reward: 217.0095817905216
# Iteration: 151 | Epsilon: 0.02 | Last Reward: -0.03 | Average100: 125 | Total Reward: 160.44388486648805
# Iteration: 152 | Epsilon: 0.02 | Last Reward: 100 | Average100: 127 | Total Reward: 225.28547155291096
# Iteration: 153 | Epsilon: 0.02 | Last Reward: -0.22 | Average100: 128 | Total Reward: 174.89338969236084
# Iteration: 154 | Epsilon: 0.02 | Last Reward: 0.69 | Average100: 128 | Total Reward: -2.0153040765266907
# Iteration: 155 | Epsilon: 0.02 | Last Reward: 100 | Average100: 131 | Total Reward: 269.3250366320739
# Iteration: 156 | Epsilon: 0.02 | Last Reward: 100 | Average100: 134 | Total Reward: 275.16644912882316
# Iteration: 157 | Epsilon: 0.02 | Last Reward: 100 | Average100: 136 | Total Reward: 247.06386304667862
# Iteration: 158 | Epsilon: 0.02 | Last Reward: -100 | Average100: 135 | Total Reward: 25.313580408150074
# Iteration: 159 | Epsilon: 0.02 | Last Reward: -100 | Average100: 135 | Total Reward: 47.967920134404295
# Iteration: 160 | Epsilon: 0.02 | Last Reward: 100 | Average100: 137 | Total Reward: 261.31340459986086
# Iteration: 161 | Epsilon: 0.02 | Last Reward: -100 | Average100: 136 | Total Reward: 34.88579329410294
# Iteration: 162 | Epsilon: 0.02 | Last Reward: -100 | Average100: 136 | Total Reward: 62.222057007713204
# Iteration: 163 | Epsilon: 0.02 | Last Reward: 100 | Average100: 138 | Total Reward: 224.8112047317017
# Iteration: 164 | Epsilon: 0.02 | Last Reward: 100 | Average100: 139 | Total Reward: 211.17828733729849
# Iteration: 165 | Epsilon: 0.01 | Last Reward: 100 | Average100: 140 | Total Reward: 227.33859805101298
# Iteration: 166 | Epsilon: 0.01 | Last Reward: 100 | Average100: 142 | Total Reward: 231.71370878877295
# Iteration: 167 | Epsilon: 0.01 | Last Reward: -100 | Average100: 140 | Total Reward: -148.89888792783296
# Iteration: 168 | Epsilon: 0.01 | Last Reward: -0.04 | Average100: 140 | Total Reward: 102.42078528738627
# Iteration: 169 | Epsilon: 0.01 | Last Reward: 100 | Average100: 141 | Total Reward: 172.01996761610405
# Iteration: 170 | Epsilon: 0.01 | Last Reward: -100 | Average100: 141 | Total Reward: 36.42216798727185
# Iteration: 171 | Epsilon: 0.01 | Last Reward: 100 | Average100: 142 | Total Reward: 235.7294725086384
# Iteration: 172 | Epsilon: 0.01 | Last Reward: -100 | Average100: 141 | Total Reward: 15.035617269425515
# Iteration: 173 | Epsilon: 0.01 | Last Reward: -100 | Average100: 141 | Total Reward: 53.33371191671196
# Iteration: 174 | Epsilon: 0.01 | Last Reward: 100 | Average100: 143 | Total Reward: 239.26688794423072
# Iteration: 175 | Epsilon: 0.01 | Last Reward: -100 | Average100: 140 | Total Reward: -128.7416622538904
# Iteration: 176 | Epsilon: 0.01 | Last Reward: -100 | Average100: 140 | Total Reward: 48.00263168327015
# Iteration: 177 | Epsilon: 0.01 | Last Reward: -100 | Average100: 137 | Total Reward: -100.59556677158595
# Iteration: 178 | Epsilon: 0.01 | Last Reward: -100 | Average100: 135 | Total Reward: 16.535442188330336
# Iteration: 179 | Epsilon: 0.01 | Last Reward: -100 | Average100: 135 | Total Reward: 43.01613482974989
# Iteration: 180 | Epsilon: 0.01 | Last Reward: -100 | Average100: 135 | Total Reward: 15.090005630395183
# Iteration: 181 | Epsilon: 0.01 | Last Reward: -100 | Average100: 133 | Total Reward: -98.85885699568418
# Iteration: 182 | Epsilon: 0.01 | Last Reward: -100 | Average100: 132 | Total Reward: 14.692196934069315
# Iteration: 183 | Epsilon: 0.01 | Last Reward: -100 | Average100: 126 | Total Reward: -477.25993190837835
# Iteration: 184 | Epsilon: 0.01 | Last Reward: -100 | Average100: 126 | Total Reward: 40.68930740921476
# Iteration: 185 | Epsilon: 0.01 | Last Reward: -100 | Average100: 127 | Total Reward: 42.38933028519304
# Iteration: 186 | Epsilon: 0.01 | Last Reward: -100 | Average100: 129 | Total Reward: 21.688607933467253
# Iteration: 187 | Epsilon: 0.01 | Last Reward: -100 | Average100: 130 | Total Reward: 10.370631772240401
# Iteration: 188 | Epsilon: 0.01 | Last Reward: 0.02 | Average100: 130 | Total Reward: 150.24009641434125
# Iteration: 189 | Epsilon: 0.01 | Last Reward: 100 | Average100: 132 | Total Reward: 239.47565254460943
# Iteration: 190 | Epsilon: 0.01 | Last Reward: -0.01 | Average100: 131 | Total Reward: 136.0887200874444
# Iteration: 191 | Epsilon: 0.01 | Last Reward: 0.02 | Average100: 132 | Total Reward: 132.9325649629226
# Iteration: 192 | Epsilon: 0.01 | Last Reward: 1.9 | Average100: 130 | Total Reward: -44.14289885749941
# Iteration: 193 | Epsilon: 0.01 | Last Reward: -100 | Average100: 127 | Total Reward: 23.777037137616148
# Iteration: 194 | Epsilon: 0.01 | Last Reward: 100 | Average100: 127 | Total Reward: 238.9111392621769
# Iteration: 195 | Epsilon: 0.01 | Last Reward: -0.4 | Average100: 127 | Total Reward: 124.77525025135056
# Iteration: 196 | Epsilon: 0.01 | Last Reward: 1.0 | Average100: 125 | Total Reward: 133.77024136335558
# Iteration: 197 | Epsilon: 0.01 | Last Reward: 100 | Average100: 127 | Total Reward: 194.75261203250892
# Iteration: 198 | Epsilon: 0.01 | Last Reward: 100 | Average100: 127 | Total Reward: 276.22110963634896
# Iteration: 199 | Epsilon: 0.01 | Last Reward: -0.02 | Average100: 126 | Total Reward: 163.85222797487526
# Iteration: 200 | Epsilon: 0.01 | Last Reward: -100 | Average100: 125 | Total Reward: 36.60366652347142
# Iteration: 201 | Epsilon: 0.01 | Last Reward: -0.01 | Average100: 125 | Total Reward: 137.3815064788185
# Iteration: 202 | Epsilon: 0.01 | Last Reward: -100 | Average100: 124 | Total Reward: 28.23251556031485
# Iteration: 203 | Epsilon: 0.01 | Last Reward: -100 | Average100: 124 | Total Reward: 27.889076551356382
# Iteration: 204 | Epsilon: 0.01 | Last Reward: -0.14 | Average100: 124 | Total Reward: 137.64042732997922
# Iteration: 205 | Epsilon: 0.01 | Last Reward: -100 | Average100: 126 | Total Reward: 39.783050109105574
# Iteration: 206 | Epsilon: 0.01 | Last Reward: 100 | Average100: 127 | Total Reward: 238.5298088319724
# Iteration: 207 | Epsilon: 0.01 | Last Reward: -100 | Average100: 125 | Total Reward: 51.50574406897789
# Iteration: 208 | Epsilon: 0.01 | Last Reward: 100 | Average100: 125 | Total Reward: 240.64799320306
# Iteration: 209 | Epsilon: 0.0 | Last Reward: 0.11 | Average100: 124 | Total Reward: 143.0945898828899
# Iteration: 210 | Epsilon: 0.0 | Last Reward: -100 | Average100: 124 | Total Reward: 33.26211356456457
# Iteration: 211 | Epsilon: 0.0 | Last Reward: 100 | Average100: 126 | Total Reward: 169.2717450127064
# Iteration: 212 | Epsilon: 0.0 | Last Reward: 100 | Average100: 128 | Total Reward: 265.28780365084015
# Iteration: 213 | Epsilon: 0.0 | Last Reward: 100 | Average100: 128 | Total Reward: 200.72357862365237
# Iteration: 214 | Epsilon: 0.0 | Last Reward: 0.06 | Average100: 128 | Total Reward: 120.10730406082796
# Iteration: 215 | Epsilon: 0.0 | Last Reward: 100 | Average100: 128 | Total Reward: 276.64033096470683
# Iteration: 216 | Epsilon: 0.0 | Last Reward: 100 | Average100: 129 | Total Reward: 247.8776632707741
# Iteration: 217 | Epsilon: 0.0 | Last Reward: -100 | Average100: 127 | Total Reward: 13.526270511290235
# Iteration: 218 | Epsilon: 0.0 | Last Reward: -100 | Average100: 125 | Total Reward: 19.34188799741426
# Iteration: 219 | Epsilon: 0.0 | Last Reward: -100 | Average100: 121 | Total Reward: -183.22874492524136
# Iteration: 220 | Epsilon: 0.0 | Last Reward: -100 | Average100: 119 | Total Reward: 16.055145072847765
# Iteration: 221 | Epsilon: 0.0 | Last Reward: 100 | Average100: 120 | Total Reward: 223.38859274663656
# Iteration: 222 | Epsilon: 0.0 | Last Reward: -100 | Average100: 119 | Total Reward: 12.301110743125292
# Iteration: 223 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 227.05570097878652
# Iteration: 224 | Epsilon: 0.0 | Last Reward: -100 | Average100: 116 | Total Reward: 25.705087333283885
# Iteration: 225 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 295.66059364314526
# Iteration: 226 | Epsilon: 0.0 | Last Reward: 0.07 | Average100: 118 | Total Reward: 118.20330537594552
# Iteration: 227 | Epsilon: 0.0 | Last Reward: -0.28 | Average100: 118 | Total Reward: 140.12997666783994
# Iteration: 228 | Epsilon: 0.0 | Last Reward: -0.14 | Average100: 117 | Total Reward: -50.384698990534496
# Iteration: 229 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 260.1551834809686
# Iteration: 230 | Epsilon: 0.0 | Last Reward: -100 | Average100: 117 | Total Reward: 61.26253256533215
# Iteration: 231 | Epsilon: 0.0 | Last Reward: 100 | Average100: 117 | Total Reward: 276.99313055245733
# Iteration: 232 | Epsilon: 0.0 | Last Reward: -100 | Average100: 115 | Total Reward: 24.255299809123315
# Iteration: 233 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 218.2134929845776
# Iteration: 234 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 190.0349468792578
# Iteration: 235 | Epsilon: 0.0 | Last Reward: -0.13 | Average100: 117 | Total Reward: 161.62328891859863
# Iteration: 236 | Epsilon: 0.0 | Last Reward: -0.1 | Average100: 116 | Total Reward: 100.85062442230182
# Iteration: 237 | Epsilon: 0.0 | Last Reward: -0.13 | Average100: 115 | Total Reward: 110.3999550782454
# Iteration: 238 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 275.54481004373923
# Iteration: 239 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 182.59080239982057
# Iteration: 240 | Epsilon: 0.0 | Last Reward: 100 | Average100: 117 | Total Reward: 174.74930052787568
# Iteration: 241 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 248.1358634119595
# Iteration: 242 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 204.91463653729568
# Iteration: 243 | Epsilon: 0.0 | Last Reward: -0.33 | Average100: 117 | Total Reward: 154.7176996315665
# Iteration: 244 | Epsilon: 0.0 | Last Reward: -0.31 | Average100: 116 | Total Reward: 138.92609856673218
# Iteration: 245 | Epsilon: 0.0 | Last Reward: 0.02 | Average100: 116 | Total Reward: 140.48886520202512
# Iteration: 246 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 285.0555755046498
# Iteration: 247 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 204.5642598534293
# Iteration: 248 | Epsilon: 0.0 | Last Reward: 0.05 | Average100: 115 | Total Reward: 142.37561613566294
# Iteration: 249 | Epsilon: 0.0 | Last Reward: -0.07 | Average100: 118 | Total Reward: 156.99434015994547
# Iteration: 250 | Epsilon: 0.0 | Last Reward: -100 | Average100: 116 | Total Reward: 33.67269415598901
# Iteration: 251 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 176.0610526022844
# Iteration: 252 | Epsilon: 0.0 | Last Reward: -0.0 | Average100: 115 | Total Reward: 151.7099687419123
# Iteration: 253 | Epsilon: 0.0 | Last Reward: 100 | Average100: 117 | Total Reward: 288.0661769738962
# Iteration: 254 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 189.3216976973128
# Iteration: 255 | Epsilon: 0.0 | Last Reward: -0.05 | Average100: 117 | Total Reward: 96.19701140166589
# Iteration: 256 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 215.27623525856302
# Iteration: 257 | Epsilon: 0.0 | Last Reward: 100 | Average100: 116 | Total Reward: 203.05698592088646
# Iteration: 258 | Epsilon: 0.0 | Last Reward: -100 | Average100: 116 | Total Reward: 52.06278486103625
# Iteration: 259 | Epsilon: 0.0 | Last Reward: 100 | Average100: 117 | Total Reward: 200.88124647812327
# Iteration: 260 | Epsilon: 0.0 | Last Reward: -0.62 | Average100: 116 | Total Reward: 133.98707073516545
# Iteration: 261 | Epsilon: 0.0 | Last Reward: 100 | Average100: 118 | Total Reward: 201.50332857304383
# Iteration: 262 | Epsilon: 0.0 | Last Reward: 100 | Average100: 119 | Total Reward: 191.8402280535895
# Iteration: 263 | Epsilon: 0.0 | Last Reward: 100 | Average100: 119 | Total Reward: 237.58515804190395
# Iteration: 264 | Epsilon: 0.0 | Last Reward: 100 | Average100: 119 | Total Reward: 204.5886657656627
# Iteration: 265 | Epsilon: 0.0 | Last Reward: -0.54 | Average100: 118 | Total Reward: 126.52167799072825
# Iteration: 266 | Epsilon: 0.0 | Last Reward: 0.54 | Average100: 117 | Total Reward: 156.2171925975857
# Iteration: 267 | Epsilon: 0.0 | Last Reward: 100 | Average100: 121 | Total Reward: 234.4342524617596
# Iteration: 268 | Epsilon: 0.0 | Last Reward: 1.32 | Average100: 120 | Total Reward: -34.48859732972431
# Iteration: 269 | Epsilon: 0.0 | Last Reward: -100 | Average100: 119 | Total Reward: 46.547783748432494
# Iteration: 270 | Epsilon: 0.0 | Last Reward: 0.0 | Average100: 120 | Total Reward: 151.18484826460184
# Iteration: 271 | Epsilon: 0.0 | Last Reward: -0.09 | Average100: 119 | Total Reward: 164.74437133536455
# Iteration: 272 | Epsilon: 0.0 | Last Reward: -0.09 | Average100: 120 | Total Reward: 146.8967712174253
# Iteration: 273 | Epsilon: 0.0 | Last Reward: -0.16 | Average100: 121 | Total Reward: 68.45899198751552
# Iteration: 274 | Epsilon: 0.0 | Last Reward: 100 | Average100: 121 | Total Reward: 252.27548638577082
# Iteration: 275 | Epsilon: 0.0 | Last Reward: 100 | Average100: 124 | Total Reward: 199.52183011366617
# Iteration: 276 | Epsilon: 0.0 | Last Reward: -100 | Average100: 123 | Total Reward: -23.232856677109694
# Iteration: 277 | Epsilon: 0.0 | Last Reward: 100 | Average100: 127 | Total Reward: 258.04376563634423
# Iteration: 278 | Epsilon: 0.0 | Last Reward: 0.01 | Average100: 128 | Total Reward: 114.73522585609103
# Iteration: 279 | Epsilon: 0.0 | Last Reward: -100 | Average100: 128 | Total Reward: 62.323369364976315
# Iteration: 280 | Epsilon: 0.0 | Last Reward: 100 | Average100: 130 | Total Reward: 166.98258790633963
# Iteration: 281 | Epsilon: 0.0 | Last Reward: 100 | Average100: 133 | Total Reward: 270.266340035844
# Iteration: 282 | Epsilon: 0.0 | Last Reward: 100 | Average100: 135 | Total Reward: 231.02267413522668
# Iteration: 283 | Epsilon: 0.0 | Last Reward: 100 | Average100: 143 | Total Reward: 259.92169750915014
# Iteration: 284 | Epsilon: 0.0 | Last Reward: 100 | Average100: 145 | Total Reward: 287.4183622933946
# Iteration: 285 | Epsilon: 0.0 | Last Reward: 100 | Average100: 147 | Total Reward: 239.8348425866679
# Iteration: 286 | Epsilon: 0.0 | Last Reward: -100 | Average100: 147 | Total Reward: 16.690298899202986
# Iteration: 287 | Epsilon: 0.0 | Last Reward: 100 | Average100: 150 | Total Reward: 274.85639486655515
# Iteration: 288 | Epsilon: 0.0 | Last Reward: 100 | Average100: 151 | Total Reward: 238.07434339764404
# Iteration: 289 | Epsilon: 0.0 | Last Reward: 100 | Average100: 150 | Total Reward: 194.1962684238385
# Iteration: 290 | Epsilon: 0.0 | Last Reward: -0.38 | Average100: 150 | Total Reward: 122.51486539645856
# Iteration: 291 | Epsilon: 0.0 | Last Reward: -100 | Average100: 146 | Total Reward: -262.5345772471028
# Iteration: 292 | Epsilon: 0.0 | Last Reward: -100 | Average100: 143 | Total Reward: -352.26084995359577
# Iteration: 293 | Epsilon: 0.0 | Last Reward: -100 | Average100: 142 | Total Reward: -69.87216280451965
# Iteration: 294 | Epsilon: 0.0 | Last Reward: -100 | Average100: 140 | Total Reward: 33.94549283779892
# Iteration: 295 | Epsilon: 0.0 | Last Reward: 100 | Average100: 141 | Total Reward: 219.5772241569295
# Iteration: 296 | Epsilon: 0.0 | Last Reward: 100 | Average100: 142 | Total Reward: 226.25930663905206
# Iteration: 297 | Epsilon: 0.0 | Last Reward: -100 | Average100: 137 | Total Reward: -295.9249498863283
# Iteration: 298 | Epsilon: 0.0 | Last Reward: -0.08 | Average100: 135 | Total Reward: 95.40089112985055
# Iteration: 299 | Epsilon: 0.0 | Last Reward: -0.94 | Average100: 135 | Total Reward: 102.78382177689156
# Iteration: 300 | Epsilon: 0.0 | Last Reward: -100 | Average100: 134 | Total Reward: -69.58085760963321
# Iteration: 301 | Epsilon: 0.0 | Last Reward: -100 | Average100: 133 | Total Reward: 31.84920714841968
# Iteration: 302 | Epsilon: 0.0 | Last Reward: -100 | Average100: 132 | Total Reward: -64.68316301355554
# Iteration: 303 | Epsilon: 0.0 | Last Reward: 100 | Average100: 134 | Total Reward: 221.261365962255
# Iteration: 304 | Epsilon: 0.0 | Last Reward: -100 | Average100: 128 | Total Reward: -430.2769923719196
# Iteration: 305 | Epsilon: 0.0 | Last Reward: -0.01 | Average100: 129 | Total Reward: 121.73020856372979
# Iteration: 306 | Epsilon: 0.0 | Last Reward: -100 | Average100: 126 | Total Reward: -26.87930002460729
# Iteration: 307 | Epsilon: 0.0 | Last Reward: 0.02 | Average100: 127 | Total Reward: 144.98155226361226
# Iteration: 308 | Epsilon: 0.0 | Last Reward: 100 | Average100: 127 | Total Reward: 235.77106230203944
# Iteration: 309 | Epsilon: 0.0 | Last Reward: 0.56 | Average100: 127 | Total Reward: 127.03730605456815
# Iteration: 310 | Epsilon: 0.0 | Last Reward: -0.39 | Average100: 128 | Total Reward: 126.8784811262359
# Iteration: 311 | Epsilon: 0.0 | Last Reward: 100 | Average100: 128 | Total Reward: 220.57598169583605
# Iteration: 312 | Epsilon: 0.0 | Last Reward: -0.06 | Average100: 127 | Total Reward: 108.66974922286384
# Iteration: 313 | Epsilon: 0.0 | Last Reward: 0.01 | Average100: 126 | Total Reward: 111.4031401733476
# Iteration: 314 | Epsilon: 0.0 | Last Reward: -100 | Average100: 125 | Total Reward: 18.648877242143257
# Iteration: 315 | Epsilon: 0.0 | Last Reward: 0.13 | Average100: 123 | Total Reward: 126.26282976269563
# Iteration: 316 | Epsilon: 0.0 | Last Reward: -0.15 | Average100: 122 | Total Reward: 116.853942011623
# Iteration: 317 | Epsilon: 0.0 | Last Reward: 100 | Average100: 124 | Total Reward: 272.3113453796816
# Iteration: 318 | Epsilon: 0.0 | Last Reward: 100 | Average100: 127 | Total Reward: 268.70851861814685
# Iteration: 319 | Epsilon: 0.0 | Last Reward: 100 | Average100: 131 | Total Reward: 232.89356031092262
# Iteration: 320 | Epsilon: 0.0 | Last Reward: 100 | Average100: 134 | Total Reward: 269.4229730079596
# Iteration: 321 | Epsilon: 0.0 | Last Reward: 100 | Average100: 134 | Total Reward: 254.5292430026048
# Iteration: 322 | Epsilon: 0.0 | Last Reward: -100 | Average100: 134 | Total Reward: -28.52327026696436
# Iteration: 323 | Epsilon: 0.0 | Last Reward: 100 | Average100: 134 | Total Reward: 254.6167386896615
# Iteration: 324 | Epsilon: 0.0 | Last Reward: 100 | Average100: 136 | Total Reward: 253.6296527220606
# Iteration: 325 | Epsilon: 0.0 | Last Reward: 100 | Average100: 136 | Total Reward: 279.9235788047265
# Iteration: 326 | Epsilon: 0.0 | Last Reward: 100 | Average100: 137 | Total Reward: 238.95783332892714
# Iteration: 327 | Epsilon: 0.0 | Last Reward: -100 | Average100: 136 | Total Reward: 61.073952323990966
# Iteration: 328 | Epsilon: 0.0 | Last Reward: 100 | Average100: 139 | Total Reward: 235.73380753447162
# Iteration: 329 | Epsilon: 0.0 | Last Reward: -100 | Average100: 137 | Total Reward: 79.39019616841756
# Iteration: 330 | Epsilon: 0.0 | Last Reward: 0.19 | Average100: 139 | Total Reward: 171.01167579456137
# Iteration: 331 | Epsilon: 0.0 | Last Reward: -100 | Average100: 136 | Total Reward: -10.873536164733082
# Iteration: 332 | Epsilon: 0.0 | Last Reward: 0.14 | Average100: 137 | Total Reward: 180.96946127451906
# Iteration: 333 | Epsilon: 0.0 | Last Reward: -0.05 | Average100: 136 | Total Reward: 117.29675111304635
# Iteration: 334 | Epsilon: 0.0 | Last Reward: 100 | Average100: 137 | Total Reward: 243.92921095703298
# Iteration: 335 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 281.9257092328635
# Iteration: 336 | Epsilon: 0.0 | Last Reward: -0.07 | Average100: 138 | Total Reward: 140.76186793778825
# Iteration: 337 | Epsilon: 0.0 | Last Reward: 100 | Average100: 140 | Total Reward: 278.7891905786586
# Iteration: 338 | Epsilon: 0.0 | Last Reward: 100 | Average100: 140 | Total Reward: 259.0754778283645
# Iteration: 339 | Epsilon: 0.0 | Last Reward: 0.11 | Average100: 139 | Total Reward: 112.47171412521159
# Iteration: 340 | Epsilon: 0.0 | Last Reward: 100 | Average100: 140 | Total Reward: 278.89721207913374
# Iteration: 341 | Epsilon: 0.0 | Last Reward: 0.0 | Average100: 139 | Total Reward: 155.0625287957228
# Iteration: 342 | Epsilon: 0.0 | Last Reward: 100 | Average100: 140 | Total Reward: 275.7390899680171
# Iteration: 343 | Epsilon: 0.0 | Last Reward: 100 | Average100: 140 | Total Reward: 202.41656772234757
# Iteration: 344 | Epsilon: 0.0 | Last Reward: -0.15 | Average100: 140 | Total Reward: 116.70045037111647
# Iteration: 345 | Epsilon: 0.0 | Last Reward: -100 | Average100: 139 | Total Reward: 38.32278934256598
# Iteration: 346 | Epsilon: 0.0 | Last Reward: -100 | Average100: 137 | Total Reward: 60.36665813398059
# Iteration: 347 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 255.91488146601085
# Iteration: 348 | Epsilon: 0.0 | Last Reward: 100 | Average100: 139 | Total Reward: 272.7543122832758
# Iteration: 349 | Epsilon: 0.0 | Last Reward: -100 | Average100: 138 | Total Reward: 65.15623175334824
# Iteration: 350 | Epsilon: 0.0 | Last Reward: -100 | Average100: 138 | Total Reward: 7.788833339365198
# Iteration: 351 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 254.33955651167213
# Iteration: 352 | Epsilon: 0.0 | Last Reward: -0.05 | Average100: 138 | Total Reward: 151.70776307550233
# Iteration: 353 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 249.70590077064006
# Iteration: 354 | Epsilon: 0.0 | Last Reward: 100 | Average100: 139 | Total Reward: 266.7202284597547
# Iteration: 355 | Epsilon: 0.0 | Last Reward: -0.42 | Average100: 139 | Total Reward: 122.06549215092537
# Iteration: 356 | Epsilon: 0.0 | Last Reward: 100 | Average100: 139 | Total Reward: 252.97120518041706
# Iteration: 357 | Epsilon: 0.0 | Last Reward: 100 | Average100: 140 | Total Reward: 210.30499931126946
# Iteration: 358 | Epsilon: 0.0 | Last Reward: 0.05 | Average100: 140 | Total Reward: 116.27313599417441
# Iteration: 359 | Epsilon: 0.0 | Last Reward: -0.16 | Average100: 139 | Total Reward: 94.95241796001724
# Iteration: 360 | Epsilon: 0.0 | Last Reward: -100 | Average100: 138 | Total Reward: 16.200152215576352
# Iteration: 361 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 192.0374439200545
# Iteration: 362 | Epsilon: 0.0 | Last Reward: -0.19 | Average100: 137 | Total Reward: 154.4291916738258
# Iteration: 363 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 247.8290837320066
# Iteration: 364 | Epsilon: 0.0 | Last Reward: 100 | Average100: 138 | Total Reward: 291.47116568772185
# Iteration: 365 | Epsilon: 0.0 | Last Reward: 100 | Average100: 139 | Total Reward: 182.46820593415669
# Iteration: 366 | Epsilon: 0.0 | Last Reward: -0.23 | Average100: 139 | Total Reward: 155.35328487288356
# Iteration: 367 | Epsilon: 0.0 | Last Reward: 100 | Average100: 139 | Total Reward: 276.24224577884695
# Iteration: 368 | Epsilon: 0.0 | Last Reward: 100 | Average100: 142 | Total Reward: 186.78026608766962
# Iteration: 369 | Epsilon: 0.0 | Last Reward: 100 | Average100: 143 | Total Reward: 193.0959153305689
# Iteration: 370 | Epsilon: 0.0 | Last Reward: 0.11 | Average100: 143 | Total Reward: 124.3568152045164
# Iteration: 371 | Epsilon: 0.0 | Last Reward: 100 | Average100: 144 | Total Reward: 295.36168590148213
# Iteration: 372 | Epsilon: 0.0 | Last Reward: -0.07 | Average100: 143 | Total Reward: 75.27298046749928
# Iteration: 373 | Epsilon: 0.0 | Last Reward: 100 | Average100: 145 | Total Reward: 209.75897677964377
# Iteration: 374 | Epsilon: 0.0 | Last Reward: 0.07 | Average100: 144 | Total Reward: 161.28125325138313
# Iteration: 375 | Epsilon: 0.0 | Last Reward: 100 | Average100: 144 | Total Reward: 172.33458270561556
# Iteration: 376 | Epsilon: 0.0 | Last Reward: 100 | Average100: 146 | Total Reward: 175.785886617036
# Iteration: 377 | Epsilon: 0.0 | Last Reward: 100 | Average100: 146 | Total Reward: 256.9111396268774
# Iteration: 378 | Epsilon: 0.0 | Last Reward: 100 | Average100: 146 | Total Reward: 200.68541729631727
# Iteration: 379 | Epsilon: 0.0 | Last Reward: -0.12 | Average100: 146 | Total Reward: 65.27215612505515
# Iteration: 380 | Epsilon: 0.0 | Last Reward: 100 | Average100: 146 | Total Reward: 117.78773002457734
# Iteration: 381 | Epsilon: 0.0 | Last Reward: 100 | Average100: 144 | Total Reward: 108.36073609333829
# Iteration: 382 | Epsilon: 0.0 | Last Reward: 100 | Average100: 144 | Total Reward: 240.97287449223754
# Iteration: 383 | Epsilon: 0.0 | Last Reward: 100 | Average100: 145 | Total Reward: 267.77294352236675
# Iteration: 384 | Epsilon: 0.0 | Last Reward: -100 | Average100: 142 | Total Reward: 18.904538112642214
# Iteration: 385 | Epsilon: 0.0 | Last Reward: 100 | Average100: 142 | Total Reward: 272.75032005253126
# Iteration: 386 | Epsilon: 0.0 | Last Reward: 100 | Average100: 145 | Total Reward: 263.60414737741314
# Iteration: 387 | Epsilon: 0.0 | Last Reward: 100 | Average100: 144 | Total Reward: 181.8392874955469
# Iteration: 388 | Epsilon: 0.0 | Last Reward: 100 | Average100: 143 | Total Reward: 146.8279191922876
# Iteration: 389 | Epsilon: 0.0 | Last Reward: 100 | Average100: 143 | Total Reward: 237.412557827265
# Iteration: 390 | Epsilon: 0.0 | Last Reward: 100 | Average100: 144 | Total Reward: 225.66838969898603
# Iteration: 391 | Epsilon: 0.0 | Last Reward: 100 | Average100: 149 | Total Reward: 205.76018638595008
# Iteration: 392 | Epsilon: 0.0 | Last Reward: 100 | Average100: 155 | Total Reward: 257.48344691256466
# Iteration: 393 | Epsilon: 0.0 | Last Reward: 100 | Average100: 159 | Total Reward: 282.9327631928028
# Iteration: 394 | Epsilon: 0.0 | Last Reward: 100 | Average100: 161 | Total Reward: 244.04555408397025
# Iteration: 395 | Epsilon: 0.0 | Last Reward: 0.09 | Average100: 160 | Total Reward: 155.45863037127233
# Iteration: 396 | Epsilon: 0.0 | Last Reward: 100 | Average100: 160 | Total Reward: 219.3082332291382
# Iteration: 397 | Epsilon: 0.0 | Last Reward: 100 | Average100: 164 | Total Reward: 130.77177958644154
# Iteration: 398 | Epsilon: 0.0 | Last Reward: 100 | Average100: 165 | Total Reward: 155.24304635951333
# Iteration: 399 | Epsilon: 0.0 | Last Reward: 100 | Average100: 166 | Total Reward: 225.33766090155558
# Iteration: 400 | Epsilon: 0.0 | Last Reward: 100 | Average100: 169 | Total Reward: 219.82101978635262
# Iteration: 401 | Epsilon: 0.0 | Last Reward: 100 | Average100: 170 | Total Reward: 107.55911207151573
# Iteration: 402 | Epsilon: 0.0 | Last Reward: 100 | Average100: 173 | Total Reward: 228.97791187128684
# Iteration: 403 | Epsilon: 0.0 | Last Reward: 100 | Average100: 173 | Total Reward: 255.86336650610127
# Iteration: 404 | Epsilon: 0.0 | Last Reward: -1.48 | Average100: 177 | Total Reward: -7.463305509550497
# Iteration: 405 | Epsilon: 0.0 | Last Reward: -0.08 | Average100: 177 | Total Reward: 98.64144075067559
# Iteration: 406 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 296.3228673341574
# Iteration: 407 | Epsilon: 0.0 | Last Reward: -100 | Average100: 176 | Total Reward: -320.5530202129078
# Iteration: 408 | Epsilon: 0.0 | Last Reward: 100 | Average100: 175 | Total Reward: 140.34152051751823
# Iteration: 409 | Epsilon: 0.0 | Last Reward: -0.0 | Average100: 174 | Total Reward: 87.29737343713383
# Iteration: 410 | Epsilon: 0.0 | Last Reward: 0.3 | Average100: 175 | Total Reward: 158.17228173948843
# Iteration: 411 | Epsilon: 0.0 | Last Reward: -0.0 | Average100: 174 | Total Reward: 150.07879716320622
# Iteration: 412 | Epsilon: 0.0 | Last Reward: 100 | Average100: 175 | Total Reward: 233.18297952862025
# Iteration: 413 | Epsilon: 0.0 | Last Reward: 100 | Average100: 175 | Total Reward: 152.40926456868115
# Iteration: 414 | Epsilon: 0.0 | Last Reward: 100 | Average100: 178 | Total Reward: 227.521895738316
# Iteration: 415 | Epsilon: 0.0 | Last Reward: 100 | Average100: 178 | Total Reward: 213.03010216578167
# Iteration: 416 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 277.28242886421293
# Iteration: 417 | Epsilon: 0.0 | Last Reward: -0.15 | Average100: 179 | Total Reward: 133.09914849105445
# Iteration: 418 | Epsilon: 0.0 | Last Reward: -0.01 | Average100: 178 | Total Reward: 176.61337374869336
# Iteration: 419 | Epsilon: 0.0 | Last Reward: 100 | Average100: 177 | Total Reward: 201.23736761487606
# Iteration: 420 | Epsilon: 0.0 | Last Reward: -100 | Average100: 175 | Total Reward: 20.928517622017708
# Iteration: 421 | Epsilon: 0.0 | Last Reward: 100 | Average100: 175 | Total Reward: 244.21346612233938
# Iteration: 422 | Epsilon: 0.0 | Last Reward: 0.98 | Average100: 177 | Total Reward: 173.65646782605123
# Iteration: 423 | Epsilon: 0.0 | Last Reward: 100 | Average100: 177 | Total Reward: 266.46910143593806
# Iteration: 424 | Epsilon: 0.0 | Last Reward: 100 | Average100: 176 | Total Reward: 194.84974044964207
# Iteration: 425 | Epsilon: 0.0 | Last Reward: 100 | Average100: 176 | Total Reward: 221.06928569373946
# Iteration: 426 | Epsilon: 0.0 | Last Reward: 100 | Average100: 176 | Total Reward: 271.1111373124495
# Iteration: 427 | Epsilon: 0.0 | Last Reward: 100 | Average100: 178 | Total Reward: 221.3681112748988
# Iteration: 428 | Epsilon: 0.0 | Last Reward: 100 | Average100: 178 | Total Reward: 242.11324634112492
# Iteration: 429 | Epsilon: 0.0 | Last Reward: 100 | Average100: 179 | Total Reward: 198.99499927722633
# Iteration: 430 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 240.09859066925122
# Iteration: 431 | Epsilon: 0.0 | Last Reward: 100 | Average100: 182 | Total Reward: 201.61612774561596
# Iteration: 432 | Epsilon: 0.0 | Last Reward: 100 | Average100: 182 | Total Reward: 162.2730895074984
# Iteration: 433 | Epsilon: 0.0 | Last Reward: 10.92 | Average100: 180 | Total Reward: -13.121929181133844
# Iteration: 434 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 239.97319957885048
# Iteration: 435 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 249.55409417946674
# Iteration: 436 | Epsilon: 0.0 | Last Reward: 100 | Average100: 181 | Total Reward: 217.43414225242822
# Iteration: 437 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 227.29583144815052
# Iteration: 438 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 223.43254146272602
# Iteration: 439 | Epsilon: 0.0 | Last Reward: -0.28 | Average100: 179 | Total Reward: 32.62055853198855
# Iteration: 440 | Epsilon: 0.0 | Last Reward: 100 | Average100: 179 | Total Reward: 236.84129495071647
# Iteration: 441 | Epsilon: 0.0 | Last Reward: 0.18 | Average100: 178 | Total Reward: 129.89724230868464
# Iteration: 442 | Epsilon: 0.0 | Last Reward: 100 | Average100: 178 | Total Reward: 234.0796906779901
# Iteration: 443 | Epsilon: 0.0 | Last Reward: 100 | Average100: 178 | Total Reward: 195.52524810278305
# Iteration: 444 | Epsilon: 0.0 | Last Reward: -0.26 | Average100: 178 | Total Reward: 136.8989997768738
# Iteration: 445 | Epsilon: 0.0 | Last Reward: 0.02 | Average100: 179 | Total Reward: 160.04764882033768
# Iteration: 446 | Epsilon: 0.0 | Last Reward: 100 | Average100: 181 | Total Reward: 192.505317535092
# Iteration: 447 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 189.6445168182563
# Iteration: 448 | Epsilon: 0.0 | Last Reward: 100 | Average100: 180 | Total Reward: 255.8763749542364
# Iteration: 449 | Epsilon: 0.0 | Last Reward: 100 | Average100: 181 | Total Reward: 198.706622155843
# Iteration: 450 | Epsilon: 0.0 | Last Reward: 100 | Average100: 183 | Total Reward: 195.6318231314628
# Iteration: 451 | Epsilon: 0.0 | Last Reward: 100 | Average100: 182 | Total Reward: 166.11664921945174
# Iteration: 452 | Epsilon: 0.0 | Last Reward: 100 | Average100: 183 | Total Reward: 278.9891549459201
# Iteration: 453 | Epsilon: 0.0 | Last Reward: 100 | Average100: 183 | Total Reward: 258.870893649951
# Iteration: 454 | Epsilon: 0.0 | Last Reward: 100 | Average100: 183 | Total Reward: 238.40039775896724
# Iteration: 455 | Epsilon: 0.0 | Last Reward: 0.03 | Average100: 183 | Total Reward: 85.61208818200349
# Iteration: 456 | Epsilon: 0.0 | Last Reward: 100 | Average100: 183 | Total Reward: 249.26424979646703
# Iteration: 457 | Epsilon: 0.0 | Last Reward: 100 | Average100: 183 | Total Reward: 246.51295183822168
# Iteration: 458 | Epsilon: 0.0 | Last Reward: 100 | Average100: 185 | Total Reward: 261.33135568094735
# Iteration: 459 | Epsilon: 0.0 | Last Reward: 100 | Average100: 187 | Total Reward: 286.4697134114898
# Iteration: 460 | Epsilon: 0.0 | Last Reward: 100 | Average100: 189 | Total Reward: 246.0121710443043
# Iteration: 461 | Epsilon: 0.0 | Last Reward: -0.14 | Average100: 189 | Total Reward: 177.51178894859402
# Iteration: 462 | Epsilon: 0.0 | Last Reward: 100 | Average100: 190 | Total Reward: 249.53269014262474
# Iteration: 463 | Epsilon: 0.0 | Last Reward: 100 | Average100: 189 | Total Reward: 203.25514888860678
# Iteration: 464 | Epsilon: 0.0 | Last Reward: -0.23 | Average100: 187 | Total Reward: 116.73968080794602
# Iteration: 465 | Epsilon: 0.0 | Last Reward: 100 | Average100: 188 | Total Reward: 226.72426656109008
# Iteration: 466 | Epsilon: 0.0 | Last Reward: -0.12 | Average100: 188 | Total Reward: 144.52860329515426
# Iteration: 467 | Epsilon: 0.0 | Last Reward: 100 | Average100: 188 | Total Reward: 293.75520192488057
# Iteration: 468 | Epsilon: 0.0 | Last Reward: 0.04 | Average100: 187 | Total Reward: 123.56158810506314
# Iteration: 469 | Epsilon: 0.0 | Last Reward: 0.26 | Average100: 187 | Total Reward: 127.3331757889859
# Iteration: 470 | Epsilon: 0.0 | Last Reward: 100 | Average100: 188 | Total Reward: 280.53196923829813
# Iteration: 471 | Epsilon: 0.0 | Last Reward: 0.3 | Average100: 186 | Total Reward: 96.43890046921236
# Iteration: 472 | Epsilon: 0.0 | Last Reward: 0.11 | Average100: 187 | Total Reward: 122.52784650927337
# Iteration: 473 | Epsilon: 0.0 | Last Reward: -0.16 | Average100: 186 | Total Reward: 126.00137267095126
# Iteration: 474 | Epsilon: 0.0 | Last Reward: 100 | Average100: 187 | Total Reward: 298.5124569639672
# Iteration: 475 | Epsilon: 0.0 | Last Reward: 100 | Average100: 188 | Total Reward: 217.59003450679901
# Iteration: 476 | Epsilon: 0.0 | Last Reward: 100 | Average100: 189 | Total Reward: 267.77987203775933
# Iteration: 477 | Epsilon: 0.0 | Last Reward: 100 | Average100: 189 | Total Reward: 275.0880202745227
# Iteration: 478 | Epsilon: 0.0 | Last Reward: 100 | Average100: 189 | Total Reward: 207.8706810202985
# Iteration: 479 | Epsilon: 0.0 | Last Reward: 0.52 | Average100: 190 | Total Reward: 164.1422667341301
# Iteration: 480 | Epsilon: 0.0 | Last Reward: 100 | Average100: 191 | Total Reward: 281.4907465412912
# Iteration: 481 | Epsilon: 0.0 | Last Reward: -100 | Average100: 190 | Total Reward: -7.563788462590267
# Iteration: 482 | Epsilon: 0.0 | Last Reward: 100 | Average100: 191 | Total Reward: 281.9050929938081
# Iteration: 483 | Epsilon: 0.0 | Last Reward: 100 | Average100: 191 | Total Reward: 246.71309594961838
# Iteration: 484 | Epsilon: 0.0 | Last Reward: 100 | Average100: 192 | Total Reward: 201.3720751253075
# Iteration: 485 | Epsilon: 0.0 | Last Reward: 100 | Average100: 192 | Total Reward: 246.70989701264676
# Iteration: 486 | Epsilon: 0.0 | Last Reward: 100 | Average100: 192 | Total Reward: 241.11034307525023
# Iteration: 487 | Epsilon: 0.0 | Last Reward: 100 | Average100: 193 | Total Reward: 255.85435420951111
# Iteration: 488 | Epsilon: 0.0 | Last Reward: 100 | Average100: 194 | Total Reward: 266.38908684505225
# Iteration: 489 | Epsilon: 0.0 | Last Reward: 100 | Average100: 194 | Total Reward: 256.69149202174873
# Iteration: 490 | Epsilon: 0.0 | Last Reward: 100 | Average100: 194 | Total Reward: 237.7411187158426
# Iteration: 491 | Epsilon: 0.0 | Last Reward: -0.44 | Average100: 193 | Total Reward: 100.30100376133451
# Iteration: 492 | Epsilon: 0.0 | Last Reward: -100 | Average100: 191 | Total Reward: 47.42181021809125
# Iteration: 493 | Epsilon: 0.0 | Last Reward: 100 | Average100: 190 | Total Reward: 231.59358226426173
# Iteration: 494 | Epsilon: 0.0 | Last Reward: 100 | Average100: 190 | Total Reward: 244.79096324910734
# Iteration: 495 | Epsilon: 0.0 | Last Reward: 0.03 | Average100: 191 | Total Reward: 165.8708012035225
# Iteration: 496 | Epsilon: 0.0 | Last Reward: 100 | Average100: 191 | Total Reward: 236.445663464811
# Iteration: 497 | Epsilon: 0.0 | Last Reward: 100 | Average100: 192 | Total Reward: 283.870667427667
# Iteration: 498 | Epsilon: 0.0 | Last Reward: 100 | Average100: 193 | Total Reward: 249.1861986968382
# Iteration: 499 | Epsilon: 0.0 | Last Reward: 100 | Average100: 193 | Total Reward: 200.77661893317486
# Iteration: 500 | Epsilon: 0.0 | Last Reward: 0.55 | Average100: 192 | Total Reward: 159.0402011518213
# Iteration: 501 | Epsilon: 0.0 | Last Reward: 100 | Average100: 194 | Total Reward: 237.9014472706741
# Iteration: 502 | Epsilon: 0.0 | Last Reward: -0.24 | Average100: 193 | Total Reward: 179.13486992235997
# Iteration: 503 | Epsilon: 0.0 | Last Reward: 100 | Average100: 193 | Total Reward: 246.4351448818908
# Iteration: 504 | Epsilon: 0.0 | Last Reward: 100 | Average100: 195 | Total Reward: 234.57878042408993
# Iteration: 505 | Epsilon: 0.0 | Last Reward: 100 | Average100: 197 | Total Reward: 230.58597771415464
# Iteration: 506 | Epsilon: 0.0 | Last Reward: 100 | Average100: 196 | Total Reward: 211.94145469859586
# Iteration: 507 | Epsilon: 0.0 | Last Reward: -0.09 | Average100: 200 | Total Reward: 35.850660836225856
# Iteration: 508 | Epsilon: 0.0 | Last Reward: 100 | Average100: 200 | Total Reward: 189.78096770731403
# Finished after 408 iterations.

# %%
# Memory to JSON data.
with open('/content/gdrive/My Drive/Double DQN.json', 'w') as f:
    json.dump(results_memory, f)

# %%
# Upload JSON data to notebook.
loaded_results_memory = None
with open('/content/gdrive/My Drive/Double DQN.json') as f:
    loaded_results_memory = json.loads(f.read())

print(loaded_results_memory[0])
# Out:
# [0, -374]

# %%
env.close() 
show_video()
# Out:
# <video alt="test" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
