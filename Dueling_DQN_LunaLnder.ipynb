# %% [markdown]
# Based on the following links to create this notebook:
#
# https://colab.research.google.com/drive/18LdlDDT87eb8cCTHZsXyS9ksQPzL3i6H
#
# https://colab.research.google.com/drive/1tug_bpg8RwrFOI8C6Ed-zo0OgD3yfnWy#scrollTo=bhsj7BTPHepg
#
# https://colab.research.google.com/drive/1tug_bpg8RwrFOI8C6Ed-zo0OgD3yfnWy
#
#
# To run Gym, you have to install prerequisites like xvbf,opengl & other python-dev packages using the following codes.

# %%
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 29 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 0s (2,429 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 29 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,270 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.8 [784 kB]
# Fetched 784 kB in 0s (5,897 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 163330 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.8_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.8) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.8) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/19/88/7a198a5ee3baa3d547f5a49574cd8c3913b216f5276b690b028f89ffb325/PyVirtualDisplay-2.1-py3-none-any.whl
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.3 pyvirtualdisplay-2.1
# Collecting piglet
#   Downloading https://files.pythonhosted.org/packages/11/56/6840e5f45626dc7eb7cd5dff57d11880b3113723b3b7b1fb1fa537855b75/piglet-1.0.0-py2.py3-none-any.whl
# Collecting piglet-templates
#   Downloading https://files.pythonhosted.org/packages/34/1e/49d7e0df9420eeb13a636487b8e606cf099f2ee0793159edd8ffe905125b/piglet_templates-1.1.0-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 3.3MB/s
# Collecting Parsley
#   Downloading https://files.pythonhosted.org/packages/2b/d6/4fed8d65e28a970e1c5cb33ce9c7e22e3de745e1b2ae37af051ef16aea3b/Parsley-1.3-py2.py3-none-any.whl (88kB)
#      |████████████████████████████████| 92kB 4.0MB/s
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.1.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (20.3.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (0.36.2)
# Installing collected packages: Parsley, piglet-templates, piglet
# Successfully installed Parsley-1.3 piglet-1.0.0 piglet-templates-1.1.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g7zgSVbNLpq6rXehKyvd2AH6AGZqSuZhj5FAmfamJ_I6oVtUsrOCL4
# Mounted at /content/gdrive

# %%
# This code creates a virtual display to draw game images on.
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    # %env DISPLAY = : 1

# %%
import json
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) # error only
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
import copy
from collections import deque

from IPython import display as ipythondisplay
import torch
import torchvision
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""
def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")


def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %%
# !pip install gym[box2d]

# %%
env = gym.make('LunarLanderContinuous-v2')
env.reset()
plt.imshow(env.render('rgb_array'))

# %%
state_size = env.observation_space
print("state size is:", state_size)
a = env.action_space
print("action size=", a)
state = env.reset()
print(state)

# %% [markdown]
# # Action Space
#             #is two floats [main engine, left-right engines].
#             # Main engine: -1..0 off, 0..+1 throttle from 50% to 100% power. Engine can't work with less than 50% power.
#             # Left-right:  -1.0..-0.5 fire left engine, +0.5..+1.0 fire right engine, -0.5..0.5 off
#             self.action_space = spaces.Box(-1, +1, (2,), dtype=np.float32)

# %% [markdown]
# # Action Space (continuous to discrete values)

# %%
class ActionSpace(object):
    def __init__(self, x_size, y_size):
        self.x_size = x_size
        self.y_size = y_size
        self.cache = {}
        self.build_actions_cache()

    def build_actions_cache(self):
        for i in range(self.x_size * self.y_size):
            self.cache[i] = self.get_value_by_key(i)

    def get_value_by_key(self, key):
        ind1 = int(key / self.y_size)
        ind2 = key % self.y_size
        value1 = 0 + ind1 * (1 / (self.x_size - 1))

        if ind1 == 0:
            value1 = -1
        if ind2 == 0:
            value2 = 0
        else:
            half = (self.y_size - 1) / 2
            if ind2 <= self.y_size/2:
                value2 = -0.5+- ind2 * (0.5 / (half))
            else:
                ind2 = ind2 - half
                value2 = 0.5 + ind2 * (0.5 / (half))

        return [value1, value2]

    def choose(self, key):
        return self.cache[key]


x_actions = 2
y_actions = 15  # y_actions must be an odd number.
all_actions = x_actions * y_actions
action_space = ActionSpace(x_actions, y_actions)

# %% [markdown]
# # DQN Model.

# %%
class DuelingDQN(nn.Module):
    def __init__(self, all_actions):
        super(DuelingDQN, self).__init__()

        self.fc1 = nn.Linear(8, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, all_actions)
        self.fc_value = nn.Linear(256, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        advantage = self.fc4(x)
        value = self.fc_value(x)
        return advantage + value - torch.mean(advantage)

# %% [markdown]
# # GPU/CPU

# %%
device = None
if torch.cuda.is_available():
    print("Using GPU.")
    device = torch.device('cuda:0')
else:
    print("Using CPU.")
    device = torch.device("cpu")
# Out:
# Using GPU.

# %% [markdown]
# # Replay Memory

# %%
class ReplayMemory(object):
    def __init__(self, replay_memory_size):
        self.memory = deque(maxlen=replay_memory_size)

    def size(self):
        return len(self.memory)

    def push(self, state, action, reward, observation, done):
        self.memory.append((state, action, reward, observation, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

# %% [markdown]
# # Methods

# %%
def choose_action(state, epsilon, model):
    model.eval()
    if np.random.rand() <= epsilon:
        return np.random.choice(all_actions)
    else:
        unsqueeze = state.unsqueeze(0)
        preds = model(unsqueeze)
        value, indice = torch.max(preds, 1)
        return indice[0].item()


def run_replay_experiments(model, target_model, replay_memory, optimizer, batch_size):
    optimizer.zero_grad()
    model.train()
    target_model.eval()

    x_batch = []
    x_target = []
    samples_batch = replay_memory.sample(batch_size)

    for state, action, reward, observation, done in samples_batch:
        x_batch.append(state)
        x_target.append(observation)

    x_batch = torch.stack(x_batch).to(device)
    x_target = torch.stack(x_target).to(device)

    model_preds = model(x_batch)
    model_preds_clone = model_preds.clone()
    target_preds = target_model(x_target)
    max_values, indices = torch.max(target_preds, 1)

    for index, (state, action, reward, observation, done) in enumerate(samples_batch):
        if done:
            model_preds_clone[index][action] = reward
        else:
            model_preds_clone[index][action] = reward + gama * max_values[index]

    loss = F.smooth_l1_loss(model_preds, model_preds_clone)
    loss.backward()
    optimizer.step()

# %% [markdown]
# # Parameters.

# %%
epsilon = 1
epsilon_decay = 0.975

batch_size = 256
max_iterations = 50000

reset_target = 200
steps_per_action = 1
replay_memory_size = 20000

gama = 0.99
lr = 0.00005

# %% [markdown]
# # Training the model.

# %%
env = wrap_env(env)


model = DuelingDQN(all_actions)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

if not next(model.parameters()).is_cuda:
    print('The neural network model is not working on GPU!')

average100 = deque(maxlen=100)
replay_memory = ReplayMemory(replay_memory_size)

results_memory = []
steps=0
for iteration in range(max_iterations):
    state = env.reset()
    total_reward = 0
    done = False
    state = torch.from_numpy(state).to(device)

    while not done:
        action = choose_action(state, epsilon, model)
        converted_action = action_space.choose(action)

        observation, reward, done, _ = env.step(converted_action)
        observation = torch.from_numpy(observation).to(device)
        total_reward += reward

        replay_memory.push(state, action, reward, observation, done)
        state = observation


        for i in range(steps_per_action):
            if steps % reset_target == 0:
                target_model = copy.deepcopy(model)
                target_model.to(device)  
            steps=steps+1        
            if replay_memory.size() >= batch_size:
                run_replay_experiments(model, target_model, replay_memory, optimizer, batch_size)


    average100.append(total_reward)
    epsilon *= epsilon_decay
    print(f'Iteration: {iteration} | Epsilon: {round(epsilon, 2)} | Last Reward: {round(reward, 2)} | Average100: {round(np.average(average100))} | Total Reward: {total_reward}')
    results_memory.append((iteration, round(np.average(average100))))

    if len(average100) >= 100 and np.average(average100) >= 200:
# Iteration: 136 | Epsilon: 0.03 | Last Reward: 100 | Average100: 134 | Total Reward: 219.7628269293064
# Iteration: 137 | Epsilon: 0.03 | Last Reward: 100 | Average100: 137 | Total Reward: 257.0011907243063
# Iteration: 138 | Epsilon: 0.03 | Last Reward: 100 | Average100: 139 | Total Reward: 220.32673570253417
# Iteration: 139 | Epsilon: 0.03 | Last Reward: 100 | Average100: 142 | Total Reward: 286.08961281744206
# Iteration: 140 | Epsilon: 0.03 | Last Reward: 100 | Average100: 145 | Total Reward: 275.34919729168945
# Iteration: 141 | Epsilon: 0.03 | Last Reward: 100 | Average100: 148 | Total Reward: 264.48426998239626
# Iteration: 142 | Epsilon: 0.03 | Last Reward: 100 | Average100: 151 | Total Reward: 266.21879055963785
# Iteration: 143 | Epsilon: 0.03 | Last Reward: 100 | Average100: 154 | Total Reward: 248.3569557178397
# Iteration: 144 | Epsilon: 0.03 | Last Reward: 100 | Average100: 157 | Total Reward: 290.06445612900177
# Iteration: 145 | Epsilon: 0.02 | Last Reward: 100 | Average100: 160 | Total Reward: 259.19109278160107
# Iteration: 146 | Epsilon: 0.02 | Last Reward: 100 | Average100: 164 | Total Reward: 283.87036713324073
# Iteration: 147 | Epsilon: 0.02 | Last Reward: 100 | Average100: 167 | Total Reward: 292.0599492866959
# Iteration: 148 | Epsilon: 0.02 | Last Reward: 100 | Average100: 170 | Total Reward: 255.6619077393845
# Iteration: 149 | Epsilon: 0.02 | Last Reward: 100 | Average100: 173 | Total Reward: 296.9426663626973
# Iteration: 150 | Epsilon: 0.02 | Last Reward: 100 | Average100: 178 | Total Reward: 277.03070251709914
# Iteration: 151 | Epsilon: 0.02 | Last Reward: 100 | Average100: 181 | Total Reward: 248.42042516524415
# Iteration: 152 | Epsilon: 0.02 | Last Reward: 100 | Average100: 184 | Total Reward: 259.0030383433525
# Iteration: 153 | Epsilon: 0.02 | Last Reward: 100 | Average100: 187 | Total Reward: 292.42924359007657
# Iteration: 154 | Epsilon: 0.02 | Last Reward: -100 | Average100: 188 | Total Reward: 56.050920084468146
# Iteration: 155 | Epsilon: 0.02 | Last Reward: 100 | Average100: 191 | Total Reward: 259.8487240832344
# Iteration: 156 | Epsilon: 0.02 | Last Reward: 100 | Average100: 194 | Total Reward: 305.2369131147342
# Iteration: 157 | Epsilon: 0.02 | Last Reward: 100 | Average100: 197 | Total Reward: 278.2765855357395
# Iteration: 158 | Epsilon: 0.02 | Last Reward: 100 | Average100: 200 | Total Reward: 264.9634364940127
# Finished after 58 iterations.

# %%
# Memory to JSON data.
with open('/content/gdrive/My Drive/Dueling DQN.json', 'w') as f:
    json.dump(results_memory, f)

# %%
# Upload JSON data to notebook.
loaded_results_memory = None
with open('/content/gdrive/My Drive/Dueling DQN.json') as f:
    loaded_results_memory = json.loads(f.read())

print(loaded_results_memory[0])
# Out:
# [0, -143]

# %%
env.close() 
show_video()
# Out:
# <video alt="test" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
