# %% [markdown]
# Based on the following links to create this notebook:
#
# https://colab.research.google.com/drive/18LdlDDT87eb8cCTHZsXyS9ksQPzL3i6H
#
# https://colab.research.google.com/drive/1tug_bpg8RwrFOI8C6Ed-zo0OgD3yfnWy#scrollTo=bhsj7BTPHepg
#
# https://colab.research.google.com/drive/1tug_bpg8RwrFOI8C6Ed-zo0OgD3yfnWy
#
#
# To run Gym, you have to install prerequisites like xvbf,opengl & other python-dev packages using the following codes.

# %%
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.8).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (2.1)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay) (0.3)
# Requirement already satisfied: piglet in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: piglet-templates in /usr/local/lib/python3.7/dist-packages (from piglet) (1.1.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (20.3.0)
# Requirement already satisfied: Parsley in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.3)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.1.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (0.36.2)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# This code creates a virtual display to draw game images on.
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    # %env DISPLAY = : 1

# %%
import json
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) # error only
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
import copy
from collections import deque

from IPython import display as ipythondisplay
import torch
import torchvision
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""
def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{0}" type="video/mp4" />
                </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")


def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %%
# !pip install gym[box2d]
# Out:
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.3.0)
# Requirement already satisfied: box2d-py~=2.3.5; extra == "box2d" in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (2.3.8)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[box2d]) (0.16.0)

# %%
env = gym.make('LunarLanderContinuous-v2')
env.reset()
plt.imshow(env.render('rgb_array'))

# %%
state_size = env.observation_space
print("state size is:", state_size)
a = env.action_space
print("action size=", a)
state = env.reset()
print(state)
# Out:
# state size is: Box(-inf, inf, (8,), float32)
# action size= Box(-1.0, 1.0, (2,), float32)
# [ 0.00691681  1.4182801   0.7005911   0.32708418 -0.00800816 -0.15869434
#   0.          0.        ]

# %% [markdown]
# # Action Space
#             #is two floats [main engine, left-right engines].
#             # Main engine: -1..0 off, 0..+1 throttle from 50% to 100% power. Engine can't work with less than 50% power.
#             # Left-right:  -1.0..-0.5 fire left engine, +0.5..+1.0 fire right engine, -0.5..0.5 off
#             self.action_space = spaces.Box(-1, +1, (2,), dtype=np.float32)

# %% [markdown]
# # Action Space (continuous to discrete values)

# %%
class ActionSpace(object):
    def __init__(self, x_size, y_size):
        self.x_size = x_size
        self.y_size = y_size
        self.cache = {}
        self.build_actions_cache()

    def build_actions_cache(self):
        for i in range(self.x_size * self.y_size):
            self.cache[i] = self.get_value_by_key(i)

    def get_value_by_key(self, key):
        ind1 = int(key / self.y_size)
        ind2 = key % self.y_size
        value1 = 0 + ind1 * (1 / (self.x_size - 1))

        if ind1 == 0:
            value1 = -1
        if ind2 == 0:
            value2 = 0
        else:
            half = (self.y_size - 1) / 2
            if ind2 <= self.y_size/2:
                value2 = -0.5+- ind2 * (0.5 / (half))
            else:
                ind2 = ind2 - half
                value2 = 0.5 + ind2 * (0.5 / (half))

        return [value1, value2]

    def choose(self, key):
        return self.cache[key]


x_actions = 2
y_actions = 15  # y_actions must be an odd number.
all_actions = x_actions * y_actions
action_space = ActionSpace(x_actions, y_actions)

# %% [markdown]
# # DQN Model.

# %%
class DuelingDQN(nn.Module):
    def __init__(self, all_actions):
        super(DuelingDQN, self).__init__()

        self.fc1 = nn.Linear(8, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, all_actions)
        self.fc_value = nn.Linear(256, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        advantage = self.fc4(x)
        value = self.fc_value(x)
        return advantage + value - torch.mean(advantage)

# %% [markdown]
# # GPU/CPU

# %%
device = None
if torch.cuda.is_available():
    print("Using GPU.")
    device = torch.device('cuda:0')
else:
    print("Using CPU.")
    device = torch.device("cpu")
# Out:
# Using GPU.

# %% [markdown]
# # Replay Memory

# %%
class ReplayMemory(object):
    def __init__(self, replay_memory_size):
        self.memory = deque(maxlen=replay_memory_size)

    def size(self):
        return len(self.memory)

    def push(self, state, action, reward, observation, done):
        self.memory.append((state, action, reward, observation, done))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

# %% [markdown]
# # Methods

# %%
def choose_action(state, epsilon, model):
    model.eval()
    if np.random.rand() <= epsilon:
        return np.random.choice(all_actions)
    else:
        unsqueeze = state.unsqueeze(0)
        preds = model(unsqueeze)
        value, indice = torch.max(preds, 1)
        return indice[0].item()


def run_replay_experiments(model, target_model, replay_memory, optimizer, batch_size,epsilon):
    optimizer.zero_grad()
    model.train()
    target_model.eval()

    x_batch = []
    x_target = []
    samples_batch = replay_memory.sample(batch_size)

    for state, action, reward, observation, done in samples_batch:
        x_batch.append(state)
        x_target.append(observation)

    x_batch = torch.stack(x_batch).to(device)
    x_target = torch.stack(x_target).to(device)

    model_preds = model(x_batch)
    model_preds_clone = model_preds.clone()
    target_preds = target_model(x_target)
    max_values, indices = torch.max(target_preds, 1)
    average_values=torch.mean(target_preds,dim=1)
    max_values=max_values*(1-epsilon)+average_values*(epsilon)
    for index, (state, action, reward, observation, done) in enumerate(samples_batch):
        if done:
            model_preds_clone[index][action] = reward
        else:
            model_preds_clone[index][action] = reward + gama * max_values[index]

    loss = F.smooth_l1_loss(model_preds, model_preds_clone)
    loss.backward()
    optimizer.step()

# %% [markdown]
# # Parameters.

# %%
epsilon = 1
epsilon_decay = 0.975

batch_size = 256
max_iterations = 50000

reset_target = 200
steps_per_action = 1
replay_memory_size = 20000

gama = 0.99
lr = 0.00005

# %% [markdown]
# # Training the model.

# %%
env = wrap_env(env)


model = DuelingDQN(all_actions)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)

if not next(model.parameters()).is_cuda:
    print('The neural network model is not working on GPU!')

average100 = deque(maxlen=100)
replay_memory = ReplayMemory(replay_memory_size)

results_memory = []
steps=0
for iteration in range(max_iterations):
    state = env.reset()
    total_reward = 0
    done = False
    state = torch.from_numpy(state).to(device)

    while not done:
        action = choose_action(state, epsilon, model)
        converted_action = action_space.choose(action)

        observation, reward, done, _ = env.step(converted_action)
        observation = torch.from_numpy(observation).to(device)
        total_reward += reward

        replay_memory.push(state, action, reward, observation, done)
        state = observation


        for i in range(steps_per_action):
            if steps % reset_target == 0:
                target_model = copy.deepcopy(model)
                target_model.to(device)  
            steps=steps+1        
            if replay_memory.size() >= batch_size:
                run_replay_experiments(model, target_model, replay_memory, optimizer, batch_size,epsilon)


    average100.append(total_reward)
    epsilon *= epsilon_decay
    print(f'Iteration: {iteration} | Epsilon: {round(epsilon, 2)} | Last Reward: {round(reward, 2)} | Average100: {round(np.average(average100))} | Total Reward: {total_reward}')
    results_memory.append((iteration, round(np.average(average100))))

    if len(average100) >= 100 and np.average(average100) >= 200:
        print(f'Finished after {iteration-100} iterations.')
        break
# Out:
# Iteration: 0 | Epsilon: 0.97 | Last Reward: -100 | Average100: -274 | Total Reward: -273.8036344584625
# Iteration: 1 | Epsilon: 0.95 | Last Reward: -100 | Average100: -378 | Total Reward: -482.735064183509
# Iteration: 2 | Epsilon: 0.93 | Last Reward: -100 | Average100: -392 | Total Reward: -418.4929387800122
# Iteration: 3 | Epsilon: 0.9 | Last Reward: -100 | Average100: -296 | Total Reward: -8.13295807477482
# Iteration: 4 | Epsilon: 0.88 | Last Reward: -100 | Average100: -315 | Total Reward: -394.1090786251364
# Iteration: 5 | Epsilon: 0.86 | Last Reward: -100 | Average100: -306 | Total Reward: -260.106367078159
# Iteration: 6 | Epsilon: 0.84 | Last Reward: -100 | Average100: -296 | Total Reward: -235.88502448458098
# Iteration: 7 | Epsilon: 0.82 | Last Reward: -100 | Average100: -288 | Total Reward: -229.65802659872455
# Iteration: 8 | Epsilon: 0.8 | Last Reward: -100 | Average100: -279 | Total Reward: -204.34176720959792
# Iteration: 9 | Epsilon: 0.78 | Last Reward: -100 | Average100: -256 | Total Reward: -56.66564721352195
# Iteration: 10 | Epsilon: 0.76 | Last Reward: -100 | Average100: -259 | Total Reward: -287.6602360107192
# Iteration: 11 | Epsilon: 0.74 | Last Reward: -100 | Average100: -249 | Total Reward: -138.76955212884943
# Iteration: 12 | Epsilon: 0.72 | Last Reward: -100 | Average100: -250 | Total Reward: -253.17446355485345
# Iteration: 13 | Epsilon: 0.7 | Last Reward: -100 | Average100: -247 | Total Reward: -209.97740183066702
# Iteration: 14 | Epsilon: 0.68 | Last Reward: 1.74 | Average100: -233 | Total Reward: -37.72813596132037
# Iteration: 152 | Epsilon: 0.02 | Last Reward: 100 | Average100: 150 | Total Reward: 243.39966429221747
# Iteration: 153 | Epsilon: 0.02 | Last Reward: 100 | Average100: 154 | Total Reward: 264.37625438038236
# Iteration: 154 | Epsilon: 0.02 | Last Reward: 0.34 | Average100: 154 | Total Reward: -1.2663425578855083
# Iteration: 155 | Epsilon: 0.02 | Last Reward: 100 | Average100: 157 | Total Reward: 212.2970522677758
# Iteration: 156 | Epsilon: 0.02 | Last Reward: 100 | Average100: 160 | Total Reward: 215.86694588286295
# Iteration: 157 | Epsilon: 0.02 | Last Reward: 100 | Average100: 162 | Total Reward: 229.84696835999816
# Iteration: 158 | Epsilon: 0.02 | Last Reward: 100 | Average100: 165 | Total Reward: 219.07395896612218
# Iteration: 159 | Epsilon: 0.02 | Last Reward: 100 | Average100: 167 | Total Reward: 282.6213111073379
# Iteration: 160 | Epsilon: 0.02 | Last Reward: 100 | Average100: 170 | Total Reward: 249.17888852450463
# Iteration: 161 | Epsilon: 0.02 | Last Reward: -100 | Average100: 170 | Total Reward: -40.66304339594834
# Iteration: 162 | Epsilon: 0.02 | Last Reward: 100 | Average100: 172 | Total Reward: 232.679469942416
# Iteration: 163 | Epsilon: 0.02 | Last Reward: 100 | Average100: 175 | Total Reward: 233.47381054609062
# Iteration: 164 | Epsilon: 0.02 | Last Reward: 100 | Average100: 177 | Total Reward: 242.35083975719652
# Iteration: 165 | Epsilon: 0.01 | Last Reward: 100 | Average100: 179 | Total Reward: 204.09512864939038
# Iteration: 166 | Epsilon: 0.01 | Last Reward: 100 | Average100: 181 | Total Reward: 210.16433639825334
# Iteration: 167 | Epsilon: 0.01 | Last Reward: 100 | Average100: 184 | Total Reward: 256.8946437373407
# Iteration: 168 | Epsilon: 0.01 | Last Reward: 100 | Average100: 186 | Total Reward: 224.4446553932786
# Iteration: 169 | Epsilon: 0.01 | Last Reward: 100 | Average100: 189 | Total Reward: 243.47045841773706
# Iteration: 170 | Epsilon: 0.01 | Last Reward: 100 | Average100: 192 | Total Reward: 265.806806275271
# Iteration: 171 | Epsilon: 0.01 | Last Reward: 100 | Average100: 194 | Total Reward: 253.96822797831035
# Iteration: 172 | Epsilon: 0.01 | Last Reward: 100 | Average100: 196 | Total Reward: 234.16197746804383
# Iteration: 173 | Epsilon: 0.01 | Last Reward: 100 | Average100: 199 | Total Reward: 222.4783508089372
# Iteration: 174 | Epsilon: 0.01 | Last Reward: 100 | Average100: 201 | Total Reward: 261.61624092394004
# Finished after 74 iterations.

# %%
# Memory to JSON data.
with open('/content/gdrive/My Drive/Dueling DQN.json', 'w') as f:
    json.dump(results_memory, f)

# %%
# Upload JSON data to notebook.
loaded_results_memory = None
with open('/content/gdrive/My Drive/Dueling DQN.json') as f:
    loaded_results_memory = json.loads(f.read())

print(loaded_results_memory[0])
# Out:
# [0, -274]

# %%
env.close() 
show_video()
# Out:
# <video alt="test" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
